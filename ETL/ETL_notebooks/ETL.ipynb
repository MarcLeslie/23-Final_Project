# %%
import pandas as pd
import numpy as np

# %%
file_to_load = "../../Data/Zip Code Data.csv"

# %%
zip_df = pd.read_csv(file_to_load)

# %%
zip_df.head()
# Out:
#        Zip  LAT  LNG  Num_Disp LA_City  Total_Pop  Percent_Under_18_Years  \
# 0  92258.0  NaN  NaN       NaN      No        559                     8.8
# 1  95202.0  NaN  NaN       NaN      No       6066                    24.6
# 2  96075.0  NaN  NaN       NaN      No        350                     0.0
# 3  92266.0  NaN  NaN       NaN      No        112                     0.0
# 4  93207.0  NaN  NaN       NaN      No        256                    16.8
#
#    Percent_Ages_18_to_24  Percent_18_and_Older  Percent_21_and_Older  ...  \
# 0                    7.7                  91.2                  91.2  ...
# 1                    6.4                  75.4                  73.4  ...
# 2                    5.1                 100.0                 100.0  ...
# 3                    0.0                 100.0                 100.0  ...
# 4                    7.8                  83.2                  75.4  ...
#
#    Pct_Female  Females_Median_Age  Total_Households Households_with_Children  \
# 0        41.0                  36               216                       45
# 1        51.8                  37              2926                      438
# 2        29.7                56.5               159                        0
# 3        24.1                   -                75                        0
# 4        50.8                62.4               114                       16
#
#    Pct_Households_with_Children  Pct_Owner_Occupied Pct_Renter_Occupied  \
# 0                          20.8                60.2                39.8
# 1                          15.0                 5.8                94.2
# 2                           0.0                83.0                17.0
# 3                           0.0                90.7                 9.3
# 4                          14.0                93.0                 7.0
#
#    Household_Median_Income  Household_Median_Inc_Quintiles  \
# 0                    10938                      Quintile 1
# 1                    14822                      Quintile 1
# 2                    16875                      Quintile 1
# 3                    19438                      Quintile 1
# 4                    20667                      Quintile 1
#
#    Pct_Earned_Income_Past_12_Months
# 0                              45.8
# 1                              44.1
# 2                              45.3
# 3                              38.7
# 4                              30.7
#
# [5 rows x 25 columns]

# %%
#Get rid of decimals for zip codes
zip_df['Zip'] = zip_df['Zip'].astype(str).apply(lambda x: x.replace('.0',''))

# %%
zip_df.head()
# Out:
#      Zip  LAT  LNG  Num_Disp LA_City  Total_Pop  Percent_Under_18_Years  \
# 0  92258  NaN  NaN       NaN      No        559                     8.8
# 1  95202  NaN  NaN       NaN      No       6066                    24.6
# 2  96075  NaN  NaN       NaN      No        350                     0.0
# 3  92266  NaN  NaN       NaN      No        112                     0.0
# 4  93207  NaN  NaN       NaN      No        256                    16.8
#
#    Percent_Ages_18_to_24  Percent_18_and_Older  Percent_21_and_Older  ...  \
# 0                    7.7                  91.2                  91.2  ...
# 1                    6.4                  75.4                  73.4  ...
# 2                    5.1                 100.0                 100.0  ...
# 3                    0.0                 100.0                 100.0  ...
# 4                    7.8                  83.2                  75.4  ...
#
#    Pct_Female  Females_Median_Age  Total_Households Households_with_Children  \
# 0        41.0                  36               216                       45
# 1        51.8                  37              2926                      438
# 2        29.7                56.5               159                        0
# 3        24.1                   -                75                        0
# 4        50.8                62.4               114                       16
#
#    Pct_Households_with_Children  Pct_Owner_Occupied Pct_Renter_Occupied  \
# 0                          20.8                60.2                39.8
# 1                          15.0                 5.8                94.2
# 2                           0.0                83.0                17.0
# 3                           0.0                90.7                 9.3
# 4                          14.0                93.0                 7.0
#
#    Household_Median_Income  Household_Median_Inc_Quintiles  \
# 0                    10938                      Quintile 1
# 1                    14822                      Quintile 1
# 2                    16875                      Quintile 1
# 3                    19438                      Quintile 1
# 4                    20667                      Quintile 1
#
#    Pct_Earned_Income_Past_12_Months
# 0                              45.8
# 1                              44.1
# 2                              45.3
# 3                              38.7
# 4                              30.7
#
# [5 rows x 25 columns]

# %%
la_city_df = zip_df.loc[(zip_df['LA_City']=="Yes")]

# %%
la_city_df.head()
# Out:
#       Zip        LAT         LNG  Num_Disp LA_City  Total_Pop  \
# 9   90021  34.030124 -118.241779      44.0     Yes       2945
# 11  90058  34.001842 -118.221127       9.0     Yes       2718
# 13  90013  34.046022 -118.246250       2.0     Yes      12559
# 29  90007  34.028334 -118.285077       4.0     Yes      42433
# 97  90037  34.003494 -118.287097       1.0     Yes      67640
#
#     Percent_Under_18_Years  Percent_Ages_18_to_24  Percent_18_and_Older  \
# 9                     11.3                    5.7                  88.7
# 11                    41.1                   10.4                  58.9
# 13                     3.2                    5.5                  96.8
# 29                    14.2                   38.3                  85.8
# 97                    27.8                   11.0                  72.2
#
#     Percent_21_and_Older  ...  Pct_Female  Females_Median_Age  \
# 9                   86.8  ...        38.4                35.2
# 11                  53.1  ...        58.1                25.3
# 13                  96.1  ...        36.5                40.6
# 29                  69.4  ...        48.4                25.1
# 97                  67.8  ...        49.8                32.2
#
#     Total_Households Households_with_Children  Pct_Households_with_Children  \
# 9               1734                      171                           9.9
# 11               706                      336                          47.6
# 13              7308                      256                           3.5
# 29             11919                     2213                          18.6
# 97             17699                     6455                          36.5
#
#     Pct_Owner_Occupied Pct_Renter_Occupied  Household_Median_Income  \
# 9                  9.0                91.0                    21635
# 11                12.0                88.0                    21964
# 13                 7.8                92.2                    22316
# 29                12.3                87.7                    27406
# 97                24.1                75.9                    35424
#
#     Household_Median_Inc_Quintiles  Pct_Earned_Income_Past_12_Months
# 9                       Quintile 1                              25.4
# 11                      Quintile 1                              40.9
# 13                      Quintile 1                              20.2
# 29                      Quintile 1                              41.6
# 97                      Quintile 1                              51.4
#
# [5 rows x 25 columns]
