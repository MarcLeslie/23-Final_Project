# %%
import pandas as pd
import numpy as np

# %%
file_to_load = "../../Data/Zip Code Data.csv"

# %%
zip_df = pd.read_csv(file_to_load)

# %%
zip_df.head()
# Out:
#      Zip        LAT         LNG  Num_Disp         City  Total_Pop  \
# 0  90021  34.030124 -118.241779      44.0  Los Angeles       2945
# 1  90058  34.001842 -118.221127       9.0  Los Angeles       2718
# 2  90013  34.046022 -118.246250       2.0  Los Angeles      12559
# 3  90007  34.028334 -118.285077       4.0  Los Angeles      42433
# 4  90037  34.003494 -118.287097       1.0  Los Angeles      67640
#
#    Percent_Under_18_Years  Percent_Ages_18_to_24  Percent_18_and_Older  \
# 0                    11.3                    5.7                  88.7
# 1                    41.1                   10.4                  58.9
# 2                     3.2                    5.5                  96.8
# 3                    14.2                   38.3                  85.8
# 4                    27.8                   11.0                  72.2
#
#    Percent_21_and_Older  ...  Pct_Female  Females_Median_Age  \
# 0                  86.8  ...        38.4                35.2
# ...

# %%
#Get rid of decimals for zip codes
zip_df['Zip'] = zip_df['Zip'].astype(str).apply(lambda x: x.replace('.0',''))

# %%
zip_df.head()
# Out:
#      Zip        LAT         LNG  Num_Disp         City  Total_Pop  \
# 0  90021  34.030124 -118.241779      44.0  Los Angeles       2945
# 1  90058  34.001842 -118.221127       9.0  Los Angeles       2718
# 2  90013  34.046022 -118.246250       2.0  Los Angeles      12559
# 3  90007  34.028334 -118.285077       4.0  Los Angeles      42433
# 4  90037  34.003494 -118.287097       1.0  Los Angeles      67640
#
#    Percent_Under_18_Years  Percent_Ages_18_to_24  Percent_18_and_Older  \
# 0                    11.3                    5.7                  88.7
# 1                    41.1                   10.4                  58.9
# 2                     3.2                    5.5                  96.8
# 3                    14.2                   38.3                  85.8
# 4                    27.8                   11.0                  72.2
#
#    Percent_21_and_Older  ...  Pct_Female  Females_Median_Age  \
# 0                  86.8  ...        38.4                35.2
# ...

# %%
la_city_df = zip_df.loc[(zip_df['City']=="Los Angeles")]
la_city_df.head()
# Out:
#      Zip        LAT         LNG  Num_Disp         City  Total_Pop  \
# 0  90021  34.030124 -118.241779      44.0  Los Angeles       2945
# 1  90058  34.001842 -118.221127       9.0  Los Angeles       2718
# 2  90013  34.046022 -118.246250       2.0  Los Angeles      12559
# 3  90007  34.028334 -118.285077       4.0  Los Angeles      42433
# 4  90037  34.003494 -118.287097       1.0  Los Angeles      67640
#
#    Percent_Under_18_Years  Percent_Ages_18_to_24  Percent_18_and_Older  \
# 0                    11.3                    5.7                  88.7
# 1                    41.1                   10.4                  58.9
# 2                     3.2                    5.5                  96.8
# 3                    14.2                   38.3                  85.8
# 4                    27.8                   11.0                  72.2
#
#    Percent_21_and_Older  ...  Pct_Female  Females_Median_Age  \
# 0                  86.8  ...        38.4                35.2
# ...

# %%
sac_city_df = zip_df.loc[(zip_df['City']=="Sacramento")]
sac_city_df.head()
# Out:
#        Zip    LAT     LNG  Num_Disp        City  Total_Pop  \
# 123  95815  38.60 -121.46       NaN  Sacramento      25673
# 124  95824  38.52 -121.44       NaN  Sacramento      30296
# 125  95832  38.43 -121.51       NaN  Sacramento      12114
# 126  95823  38.47 -121.44       NaN  Sacramento      79440
# 127  95838  38.64 -121.44       NaN  Sacramento      39053
#
#      Percent_Under_18_Years  Percent_Ages_18_to_24  Percent_18_and_Older  \
# 123                    27.0                   10.2                  73.0
# 124                    28.6                   11.1                  71.4
# 125                    29.6                   12.1                  70.4
# 126                    29.4                    9.2                  70.6
# 127                    29.3                   10.8                  70.7
#
#      Percent_21_and_Older  ...  Pct_Female  Females_Median_Age  \
# 123                  69.2  ...        48.5                  33
# ...
